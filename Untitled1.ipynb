# %%
from graphviz import Digraph

f = Digraph('finite_state_machine', filename='fsm.gv')
f.attr(rankdir='LR', size='8,5')

f.node('A')
f.node('B')
f.node('C')
f.node('D')
f.node('E')
f.node('F')

f.attr('node', shape='circle')
f.edge('A', 'B', label='(9,3)')
f.edge('A', 'C', label='(7,1)')
f.edge('C', 'D', label='(4,1)')
f.edge('C', 'E', label='(6,5)')
f.edge('B', 'D', label='(7,4)')
f.edge('B', 'E', label='(2,2)')

f.edge('D', 'E', label='(3,3)')
f.edge('D', 'F', label='(6,2)')
f.edge('E', 'F', label='(9,4)')


f

# %% [markdown]
# J=A
#
# 3- $\Gamma^+(A)=(C,B)$
#
# para C :[+S,1] f(C)=($\infty$,1)=1
#
# para B :[+S,3] f(C)=($\infty$,3)=3
#
# entonces el vertice 5 ah sido examindado
#
# J=C
#
# 3- $\Gamma^+(A)=(E,D)$
#
# para E : [+C,1] f(E)=(1,5)=1
#
# para D : [+C,1]  F(D)=(1,1)=1
#
# eNTONCES EL VERTICE c AH SIDO EVALUADO
