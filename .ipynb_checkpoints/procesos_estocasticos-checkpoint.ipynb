# %% [markdown]
# Una opcion adicional es hacer  una reparecion cuando la maquina presente fallas. El costo de esta es de $2000 y se lleva
# un semana
#
# En resumen , las posibles acciones (deciciones son)
#
# |Desicion|Acciones|Estados Validos|
# |--------|:------:|--------------:|
# |1|Nohacer nada|0,1,2|
# |2|reparcion general(regresa el estado 1)|2|
# |3|Remplazo(regresa al estado 0)|1,2,3|
#
# Considere estas desiciones , los costos inmediatos se resumen en:
#
# | Descision       | Estado        | Costo por articulos defectuosos  |Mantenimiento|Produccion perdida|Costo total|
# | --------------- |:-------------:|:--------------------------------:|:-----------:|:----------------:|----------:|
# | 1     | 0 <br>1<br>2 |  0<br>1000<br>3000 | 0<br>0<br>0|0<br>0<br>0 |0<br>1000<br>3000|
# | 2     |  2  |  0 | 2000| 2000|4000|
# | 3     | 1,2,3  |  0 |4000| 2000|6000|
#
#
# Con esta informacion se debe determinar por que acciones se deben realizar en cada estado para obtener el maximo beneficio
#
# se propone el siguiente modelo general.
#
# 1. Se observa el estado i de la cadena despues de cada transicion(i=0,1,...,M)
# 2. Despues de cadaa observacion se selecciona una desicion R del conjunto de K desiciones posibles (k=1,2,...,k) .Algunas no seran validas
# 3. Si se elige la desicion de $d_i=k$ en el estado i , se incurre en un costoinmediato con valor estperado $C_{ik}$
# 4. La desicon de $d_i=k$ determina cuales serán las probabilidades de transicion para la siguiente transicion desde el estado i .Denotar estas probabilidades po $p_{ij}(k)$ para j=0,1,...M
# 5. Una politica estara definida por la eleccion de una desicion para cada uno de los estados $R(d_0,d_1,....d_M)$
# 6. El objetivo es encontrar una politica optima que maximize los beneficios o minmize los costos
#
# Durante cualquier periodo , un cliente potencial  llega a una instalacio de servicio con probabilidad  $frac{1}{2}$ . si ve 2 personas  en la instalacion se va y no regresa , si hay menos de 2 personas entra y se convierte en cliente real.El administrador de cada periodo entre una de 2 configuracioes posibles . si se usa la configuracion , aun costo de 3 y si hay clientes presentes durante el periodo u cliente sera servido y se ira con probabilidad $\frac{3}{5}$ si usa la rapida,a un costo de 9, la probabilidad crece a $\frac{4}{5}$
#
# la probabilidad de que llegue mas de un cliente o se atienda a mas de uno , es cero
#
# se cobra 50 a cada cliente una vez que es servido
#
# enontrar la politica optima que beneficie el centro de servicio
#
# k=1
#
# p(1,1)=p(no llegue alguien )
#
# p(2,1)=p(que se vaya y no llego nadie)
#
#        p($\frac{3}{5}$)($\frac{1}{2}$)=$\frac{3}{10}$
#
# p(2,2)=p(no se vaya y no llegue nadie o,
#          se vaya uno y llega otro,o no se vaya nadie y llega alguien)
#
#          p(($\frac{2}{5}$)($\frac{1}{2}$)+($\frac{3}{5}$)($\frac{1}{2}$)+($\frac{2}{5}$)($\frac{1}{2}$))
#
#          =$\frc{7}{10}$
#
# matriz de costos
#
# ||1|2|
# |-|-|-|
# |0|3|-|
# |1|-27|-31|
# |2|-22|-31|
#
#
# $C_{01}$=costos por no tener clientes u usar la coniguracion lente =3
#
# $C_{02}$=no permimitido
#
# $C_{11}$= (3)(1)-(50)($\frac{3}{5}$)=-27
#
# $C_{12}$= (9)(1)-(50)($\frac{4}{5}$)=-31
#
# $C_{21}$= (3)(1)-(50)($\frac{3}{5}$)+(50)($\frac{1}{2}$)=-22
#
# $C_{22}$=-31
#
#
#
#
# cuando un jugador de tenis sirve tiene dos oportunidades para que la pelota caiga dentro de los limites .si falla dos veces pierde el punto,si intenta un servicio as tiene una probabilidad de $\frac{3}{8}$ de que caiga dentro del cuadro si saca un servicio suave la probabilidad de hacerlo bien es de $\frac{7}{8}$ si el servicio has cae dentro del cuadro gana con probabilidad de $\frac{2}{3}$ con el servicio suave dentro del cuadro la probabilidad fde ganar el punto es de $\frac{1}{3}$ el costo por ganar un punto es 1 y perder -1 encontrar la mejor politica por el metodo de mejoramiento de politicas
#
#
#
# $AS =
# \left\{
# 	\begin{array}{ll}
# 		\frac{3}{8} \text{ dentro} \\
# 		\frac{2}{3} \text{ ganar}
# 	\end{array}
# \right.$
#
# $SUAVE =
# \left\{
# 	\begin{array}{ll}
# 		\frac{7}{8} \text{ dentro} \\
# 		\frac{4}{3} \text{ ganar}
# 	\end{array}
# \right.$
#
# $COSTAS =
# \left\{
# 	\begin{array}{ll}
# 		1 \text{ ganado} \\
# 		-1 \text{ perdido}
# 	\end{array}
# \right.$
#
# $x_t$=punto ganado o perdido en el servicio t
#
# S={-1,0,1}
#
# T={1,2}
